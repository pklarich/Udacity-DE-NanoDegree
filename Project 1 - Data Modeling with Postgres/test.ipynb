# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [('0', datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 91, 'free', None, None, 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  ('1', datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('2', datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('3', datetime.datetime(2018, 11, 30, 1, 17, 5, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('4', datetime.datetime(2018, 11, 30, 1, 20, 56, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('5', datetime.datetime(2018, 11, 30, 1, 24, 32, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('6', datetime.datetime(2018, 11, 30, 1, 28, 19, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('7', datetime.datetime(2018, 11, 30, 1, 32, 0, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('9', datetime.datetime(2018, 11, 30, 1, 38, 17, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('10', datetime.datetime(2018, 11, 30, 1, 39, 53, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('11', datetime.datetime(2018, 11, 30, 1, 44, 10, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('12', datetime.datetime(2018, 11, 30, 1, 48, 36, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('13', datetime.datetime(2018, 11, 30, 1, 50, 28, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('14', datetime.datetime(2018, 11, 30, 1, 55, 35, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('15', datetime.datetime(2018, 11, 30, 2, 1, 8, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('16', datetime.datetime(2018, 11, 30, 2, 5, 24, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('17', datetime.datetime(2018, 11, 30, 2, 10, 21, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('18', datetime.datetime(2018, 11, 30, 2, 15, 54, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('19', datetime.datetime(2018, 11, 30, 2, 19, 19, 796000), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  ('23', datetime.datetime(2018, 11, 30, 3, 6, 30, 796000), 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  ('24', datetime.datetime(2018, 11, 30, 3, 10, 30, 796000), 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  ('25', datetime.datetime(2018, 11, 30, 3, 13, 3, 796000), 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  ('26', datetime.datetime(2018, 11, 30, 3, 15, 41, 796000), 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  ('27', datetime.datetime(2018, 11, 30, 3, 21, 9, 796000), 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  ('30', datetime.datetime(2018, 11, 30, 3, 29, 23, 796000), 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [(91, 'Jayden', 'Bell', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'paid'),
#  (57, 'Katherine', 'Gay', 'F', 'free'),
#  (30, 'Avery', 'Watkins', 'F', 'paid'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (74, 'Braden', 'Parker', 'M', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'paid'),
#  (36, 'Matthew', 'Jones', 'M', 'paid'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (43, 'Jahiem', 'Miles', 'M', 'free'),
#  (85, 'Kinsley', 'Young', 'F', 'paid'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (16, 'Rylan', 'George', 'M', 'paid'),
#  (78, 'Chloe', 'Roth', 'F', 'free'),
#  (33, 'Bronson', 'Harris', 'M', 'free'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, Decimal('218.93179')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, Decimal('266.39628')),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, Decimal('269.81832')),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, Decimal('189.57016')),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, Decimal('148.03546')),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, Decimal('267.7024')),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, Decimal('114.78159')),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, Decimal('218.77506')),
#  ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, Decimal('233.40363')),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, Decimal('209.60608')),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, Decimal('177.47546')),
#  ('SOUQQEA12A8C134B1B', 'High Tide', 'ARIG6O41187B988BDD', 0, Decimal('228.5971')),
#  ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 'AR1ZHYZ1187FB3C717', 0, Decimal('599.24853')),
#  ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, Decimal('491.12771')),
#  ('SOMUYGI12AB0188633', 'La Culpa', 'ARL7K851187B99ACD2', 0, Decimal('226.35057')),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, Decimal('191.84281')),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, Decimal('290.29832')),
#  ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, Decimal('151.84934')),
#  ('SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, Decimal('165.69424')),
#  ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 'ARC43071187B990240', 0, Decimal('245.21098')),
#  ('SOBEBDG12A58A76D60', 'Kassie Jones', 'ARI3BMM1187FB4255E', 0, Decimal('220.78649')),
#  ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, Decimal('307.3824')),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 'AREBBGV1187FB523D2', 0, Decimal('173.66159')),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 'ARB29H41187B98F0EF', 1972, Decimal('342.56934')),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 'ARDNS031187B9924F0', 2005, Decimal('186.48771'))]

# %%
# %sql SELECT * FROM artists LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', None, None),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', None, None),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', None, None),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', Decimal('35.14968'), Decimal('-90.04892')),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', None, None),
#  ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', Decimal('35.21962'), Decimal('-80.01955')),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', None, None),
#  ('ARXR32B1187FB57099', 'Gob', '', None, None),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', None, None),
#  ('ARIG6O41187B988BDD', 'Richard Souther', 'United States', Decimal('37.16793'), Decimal('-95.84502')),
#  ('AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', None, None),
#  ('ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', Decimal('43.64856'), Decimal('-79.38533')),
#  ('ARL7K851187B99ACD2', 'Andy Andy', '', None, None),
#  ('ARHHO3O1187B989413', 'Bob Azzam', '', None, None),
#  ('ARYKCQI1187FB3B18F', 'Tesla', '', None, None),
#  ('ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', Decimal('34.31109'), Decimal('-94.02978')),
#  ('ARNPAGP1241B9C7FD4', 'lextrical', '', None, None),
#  ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', None, None),
#  ('ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', Decimal('38.8991'), Decimal('-77.029')),
#  ('ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', None, None),
#  ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', None, None),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', Decimal('41.88415'), Decimal('-87.63241')),
#  ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', Decimal('32.67828'), Decimal('-83.22295'))]

# %%
# %sql SELECT * FROM time LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [(datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 0, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 17, 5, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 20, 56, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 24, 32, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 28, 19, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 32, 0, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 38, 17, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 39, 53, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 44, 10, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 48, 36, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 50, 28, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 55, 35, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 2, 1, 8, 796000), 2, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 2, 5, 24, 796000), 2, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 2, 10, 21, 796000), 2, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 2, 15, 54, 796000), 2, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 2, 19, 19, 796000), 2, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 6, 30, 796000), 3, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 10, 30, 796000), 3, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 13, 3, 796000), 3, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 15, 41, 796000), 3, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 21, 9, 796000), 3, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 3, 29, 23, 796000), 3, 30, 48, 11, 2018, 4)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
